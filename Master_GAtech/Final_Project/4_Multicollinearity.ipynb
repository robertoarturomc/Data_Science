# %% [markdown]
# On this notebook, variables that have high multicollinearity will be carefully removed. For this purpose, the Variance Inflation Factor (VIF) will be used.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression, Lasso
import statsmodels.api as sm

# %%
data=pd.read_pickle('Datasets/Outliers.plk')
data.head()
# Out:
#                             start_id  pbp_idx                     game_id  \
# 0  2019/04/01/anamlb-seamlb-1_433587        1  2019/04/01/anamlb-seamlb-1
# 1  2019/04/01/anamlb-seamlb-1_433587        2  2019/04/01/anamlb-seamlb-1
# 2  2019/04/01/anamlb-seamlb-1_433587        3  2019/04/01/anamlb-seamlb-1
# 3  2019/04/01/anamlb-seamlb-1_433587        4  2019/04/01/anamlb-seamlb-1
# 4  2019/04/01/anamlb-seamlb-1_433587        5  2019/04/01/anamlb-seamlb-1
#
#   top_bot  inning batter_stands  pitcher_id throws     EventType  postouts  \
# 0       Y       1             L      433587      R     field_out         1
# 1       Y       1             R      433587      R  hit_by_pitch         1
# 2       Y       1             L      433587      R     force_out         2
# 3       Y       1             R      433587      R     field_out         3
# 4       Y       2             R      433587      R        single         0
#
#    ...  pas_since_single  has_have_single  pas_since_walk  has_have_walk  \
# 0  ...               0.0            False             0.0          False
# 1  ...               0.0            False             0.0          False
# 2  ...               0.0            False             0.0          False
# 3  ...               0.0            False             0.0          False
# 4  ...               0.0             True             0.0          False
#
#    pas_since_double has_have_double  pas_since_home_run  has_have_home_run  \
# 0               0.0           False                 0.0              False
# 1               0.0           False                 0.0              False
# 2               0.0           False                 0.0              False
# 3               0.0           False                 0.0              False
# 4               0.0           False                 0.0              False
#
#    pas_since_points_allowed  has_have_points_allowed
# 0                       0.0                    False
# 1                       0.0                    False
# 2                       0.0                    False
# 3                       0.0                    False
# 4                       0.0                    False
#
# [5 rows x 99 columns]

# %%
target=data['last_batter'].copy()
starter=data['start_id'].copy()

# Drop the ids; on a separate data frame if we need them in the future.
df = data.drop(['start_id', 'game_id', #'pbp_idx',  #will be kept, as it is an important indicator of the current status.
                'top_bot', 'batter_stands', 'pitcher_id', 'EventType', 'PostVisTeamScore', 'PostHomeTeamScore', 'home_away', 'bats_right', 'throws_right', 'throws', 'next_batter_hand'], axis=1)
df.shape
# Out:
# (49398, 86)

# %%
df.head()
# Out:
#    pbp_idx  inning  postouts  post_runner_on_first  post_runner_on_second  \
# 0        1       1         1                     0                      0
# 1        2       1         1                     1                      0
# 2        3       1         2                     1                      0
# 3        4       1         3                     1                      0
# 4        5       2         0                     0                      1
#
#    post_runner_on_third  pitches_in_pa  pitch_total  er_total  \
# 0                     0              1            1         0
# 1                     0              5            6         0
# 2                     0              4           10         0
# 3                     0              4           14         0
# 4                     0              3           17         0
#
#    runners_on_base  ...  pas_since_single  has_have_single  pas_since_walk  \
# 0                0  ...               0.0            False             0.0
# 1                1  ...               0.0            False             0.0
# 2                1  ...               0.0            False             0.0
# 3                1  ...               0.0            False             0.0
# 4                1  ...               0.0             True             0.0
#
#    has_have_walk  pas_since_double  has_have_double  pas_since_home_run  \
# 0          False               0.0            False                 0.0
# 1          False               0.0            False                 0.0
# 2          False               0.0            False                 0.0
# 3          False               0.0            False                 0.0
# 4          False               0.0            False                 0.0
#
#    has_have_home_run  pas_since_points_allowed  has_have_points_allowed
# 0              False                       0.0                    False
# 1              False                       0.0                    False
# 2              False                       0.0                    False
# 3              False                       0.0                    False
# 4              False                       0.0                    False
#
# [5 rows x 86 columns]

# %%
df['constant']=1
df=df+0

X_train, X_test, y_train, y_test =train_test_split(df, target, train_size=0.8, random_state=42)

# Will only use information from the plate appearance number 18, onwards.
X_train['last_batter']=y_train
X_train=X_train[X_train.pbp_idx>18]
y_train=X_train['last_batter']

changes=X_train.loc[X_train.last_batter==1]
no_changes=X_train.loc[X_train.last_batter==0]
# Out:
# <ipython-input-5-14007494b48e>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train['last_batter']=y_train

# %%
print(changes.shape)
print(no_changes.shape)
# Out:
# (1551, 87)
# (7418, 87)

# %%
# Downsample: will keep 60% of rows from "normal" plays and 40% of "change" plays.
X_train2=pd.concat([changes, 
                    no_changes.sample(n=int(len(changes)*1.5), random_state=42)])

y_train2=X_train2.last_batter

X_train2.drop('last_batter', axis=1, inplace=True)
X_test.drop('last_batter', axis=1, inplace=True)
# Out:
# C:\Users\rober\.conda\envs\ramc\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
pd.set_option('display.max_rows', None)

# %%
vif=pd.Series([variance_inflation_factor(X_train2.values, i) 
               for i in range(X_train2.shape[1])], 
              index=X_train2.columns)

vif
# Out:
# C:\Users\rober\.conda\envs\ramc\lib\site-packages\statsmodels\stats\outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# C:\Users\rober\.conda\envs\ramc\lib\site-packages\statsmodels\regression\linear_model.py:1685: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# pbp_idx                                    inf
# inning                              351.485371
# postouts                             62.003250
# post_runner_on_first                       inf
# post_runner_on_second                      inf
# post_runner_on_third                       inf
# pitches_in_pa                         1.334409
# pitch_total                           2.800208
# er_total                             13.062530
# runners_on_base                            inf
# score_diff                            1.713676
# tying_run_on                          1.158029
# total_outs_recorded                 332.524001
# total_bases_allowed                  26.398067
# opposite_hand                         1.292357
# end_of_inning                         3.238299
# previously_walk                       1.967720
# consec_walks                          1.103528
# double_header                         1.036361
# home_team                             1.045444
# opposite_actual                       2.081144
# bats_left                             1.984126
# throws_left                           3.886171
# batter_order                          2.106598
# field_out                             7.638310
# strikeout                             5.801570
# single                                6.697777
# walk                                  4.961341
# double                                4.247991
# home_run                              4.558946
# cum_post_runner_on_first              5.352601
# inning_cum_post_runner_on_first      12.954047
# cum_post_runner_on_second             3.244302
# inning_cum_post_runner_on_second      6.508632
# cum_post_runner_on_third              2.785637
# inning_cum_post_runner_on_third       4.502548
# cum_bats_right                             inf
# inning_cum_bats_right                      inf
# cum_bats_left                              inf
# inning_cum_bats_left                       inf
# cum_opposite_actual                   4.481254
# inning_cum_opposite_actual            6.393261
# cum_field_out                         8.379346
# inning_cum_field_out                 11.728886
# cum_strikeout                         6.649966
# inning_cum_strikeout                  8.105709
# cum_single                            7.437337
# inning_cum_single                    11.277447
# cum_walk                              5.152770
# inning_cum_walk                       7.211305
# cum_double                            7.715034
# inning_cum_double                     6.875574
# cum_home_run                         18.996963
# inning_cum_home_run                   7.710882
# cum_points_allowed                   15.214936
# points_allowed                        3.278580
# inning_cum_points_allowed            45.537433
# inning_pa                                  inf
# hot_cold_field_out                    3.807391
# hot_cold_strikeout                    3.046594
# hot_cold_single                       2.443728
# hot_cold_walk                         1.763273
# hot_cold_double                       1.600205
# hot_cold_home_run                     2.430630
# hot_cold_points_allowed               2.278722
# pas_since_post_runner_on_first        3.067737
# has_have_post_runner_on_first         1.156403
# pas_since_post_runner_on_second       2.616710
# has_have_post_runner_on_second        1.836088
# pas_since_post_runner_on_third        2.753675
# has_have_post_runner_on_third         3.714101
# pas_since_field_out                   2.494751
# has_have_field_out                    0.000000
# pas_since_strikeout                   1.936786
# has_have_strikeout                    1.160888
# pas_since_single                      2.895083
# has_have_single                       1.766863
# pas_since_walk                        3.099808
# has_have_walk                         3.947756
# pas_since_double                      4.121281
# has_have_double                       6.352289
# pas_since_home_run                    4.405730
# has_have_home_run                     7.601060
# pas_since_points_allowed              2.731863
# has_have_points_allowed               2.774321
# constant                              0.000000
# dtype: float64

# %%
X_train2.drop(['post_runner_on_first', 'post_runner_on_second', 'post_runner_on_third'], axis=1, inplace=True)

vif=pd.Series([variance_inflation_factor(X_train2.values, i) 
               for i in range(X_train2.shape[1])], 
              index=X_train2.columns)

vif
# Out:
# pbp_idx                                    inf
# inning                              347.329389
# postouts                             61.964696
# pitches_in_pa                         1.332259
# pitch_total                           2.799486
# er_total                             13.061807
# runners_on_base                      31.668820
# score_diff                            1.713457
# tying_run_on                          1.156204
# total_outs_recorded                 328.650775
# total_bases_allowed                  26.360111
# opposite_hand                         1.292143
# end_of_inning                         3.234596
# previously_walk                       1.952263
# consec_walks                          1.103297
# double_header                         1.035146
# home_team                             1.045180
# opposite_actual                       2.078874
# bats_left                             1.981266
# throws_left                           3.885166
# batter_order                          2.106208
# field_out                             7.568788
# strikeout                             5.751121
# single                                6.487359
# walk                                  4.820037
# double                                3.627772
# home_run                              4.475599
# cum_post_runner_on_first              5.348260
# inning_cum_post_runner_on_first      10.286150
# cum_post_runner_on_second             3.232406
# inning_cum_post_runner_on_second      5.216189
# cum_post_runner_on_third              2.760284
# inning_cum_post_runner_on_third       3.108192
# cum_bats_right                             inf
# inning_cum_bats_right                      inf
# cum_bats_left                              inf
# inning_cum_bats_left                       inf
# cum_opposite_actual                   4.480372
# inning_cum_opposite_actual            6.386260
# cum_field_out                         8.373610
# inning_cum_field_out                 11.594667
# cum_strikeout                         6.649059
# inning_cum_strikeout                  8.019775
# cum_single                            7.432110
# inning_cum_single                    11.173871
# cum_walk                              5.148706
# inning_cum_walk                       7.145299
# cum_double                            7.709472
# inning_cum_double                     6.643851
# cum_home_run                         18.984547
# inning_cum_home_run                   7.649773
# cum_points_allowed                   15.210984
# points_allowed                        3.250709
# inning_cum_points_allowed            44.496988
# inning_pa                                  inf
# hot_cold_field_out                    3.805585
# hot_cold_strikeout                    3.043689
# hot_cold_single                       2.441857
# hot_cold_walk                         1.761642
# hot_cold_double                       1.599591
# hot_cold_home_run                     2.428702
# hot_cold_points_allowed               2.277784
# pas_since_post_runner_on_first        3.010646
# has_have_post_runner_on_first         1.154476
# pas_since_post_runner_on_second       2.421996
# has_have_post_runner_on_second        1.779329
# pas_since_post_runner_on_third        2.549961
# has_have_post_runner_on_third         3.477848
# pas_since_field_out                   2.487730
# has_have_field_out                    0.000000
# pas_since_strikeout                   1.936741
# has_have_strikeout                    1.160804
# pas_since_single                      2.893288
# has_have_single                       1.766588
# pas_since_walk                        3.099206
# has_have_walk                         3.946072
# pas_since_double                      4.097869
# has_have_double                       6.327849
# pas_since_home_run                    4.390714
# has_have_home_run                     7.565408
# pas_since_points_allowed              2.717414
# has_have_points_allowed               2.762530
# constant                              0.000000
# dtype: float64

# %%
X_train2.drop(['inning_cum_bats_right', 'inning_pa'], axis=1, inplace=True)

vif=pd.Series([variance_inflation_factor(X_train2.values, i) 
               for i in range(X_train2.shape[1])], 
              index=X_train2.columns)

vif
# Out:
# pbp_idx                                    inf
# inning                              324.199087
# postouts                             37.220408
# pitches_in_pa                         1.331227
# pitch_total                           2.799465
# er_total                             13.061792
# runners_on_base                      18.043992
# score_diff                            1.713427
# tying_run_on                          1.155820
# total_outs_recorded                 313.021260
# total_bases_allowed                  26.350583
# opposite_hand                         1.291676
# end_of_inning                         3.218101
# previously_walk                       1.943658
# consec_walks                          1.103293
# double_header                         1.034937
# home_team                             1.045073
# opposite_actual                       2.068024
# bats_left                             1.978284
# throws_left                           3.885074
# batter_order                          2.106203
# field_out                             6.643423
# strikeout                             5.161143
# single                                5.874090
# walk                                  4.549650
# double                                3.348975
# home_run                              4.226949
# cum_post_runner_on_first              5.249947
# inning_cum_post_runner_on_first       9.392202
# cum_post_runner_on_second             3.209636
# inning_cum_post_runner_on_second      5.016778
# cum_post_runner_on_third              2.734411
# inning_cum_post_runner_on_third       3.006251
# cum_bats_right                             inf
# cum_bats_left                              inf
# inning_cum_bats_left                  4.439192
# cum_opposite_actual                   4.461971
# inning_cum_opposite_actual            6.266226
# cum_field_out                         8.281086
# inning_cum_field_out                 10.676155
# cum_strikeout                         6.584253
# inning_cum_strikeout                  7.543075
# cum_single                            7.362679
# inning_cum_single                    10.121112
# cum_walk                              5.099407
# inning_cum_walk                       6.725998
# cum_double                            7.642402
# inning_cum_double                     6.004954
# cum_home_run                         18.885920
# inning_cum_home_run                   6.828549
# cum_points_allowed                   15.149356
# points_allowed                        3.218191
# inning_cum_points_allowed            17.644236
# hot_cold_field_out                    3.804764
# hot_cold_strikeout                    3.042567
# hot_cold_single                       2.440381
# hot_cold_walk                         1.761076
# hot_cold_double                       1.597972
# hot_cold_home_run                     2.427911
# hot_cold_points_allowed               2.276411
# pas_since_post_runner_on_first        3.009674
# has_have_post_runner_on_first         1.154415
# pas_since_post_runner_on_second       2.421023
# has_have_post_runner_on_second        1.778566
# pas_since_post_runner_on_third        2.548463
# has_have_post_runner_on_third         3.475671
# pas_since_field_out                   2.468252
# has_have_field_out                    0.000000
# pas_since_strikeout                   1.934460
# has_have_strikeout                    1.160672
# pas_since_single                      2.893272
# has_have_single                       1.766241
# pas_since_walk                        3.093317
# has_have_walk                         3.944663
# pas_since_double                      4.091776
# has_have_double                       6.323548
# pas_since_home_run                    4.388233
# has_have_home_run                     7.564368
# pas_since_points_allowed              2.716582
# has_have_points_allowed               2.762529
# constant                              0.000000
# dtype: float64

# %%
X_train2.drop(['total_outs_recorded'], axis=1, inplace=True)

vif=pd.Series([variance_inflation_factor(X_train2.values, i) 
               for i in range(X_train2.shape[1])], 
              index=X_train2.columns)

vif
# Out:
# pbp_idx                                   inf
# inning                              20.937132
# postouts                            16.126162
# pitches_in_pa                        1.331217
# pitch_total                          2.798351
# er_total                            12.996944
# runners_on_base                     15.674353
# score_diff                           1.713426
# tying_run_on                         1.155812
# total_bases_allowed                 25.890330
# opposite_hand                        1.291172
# end_of_inning                        3.217982
# previously_walk                      1.908723
# consec_walks                         1.100516
# double_header                        1.034232
# home_team                            1.045025
# opposite_actual                      2.067031
# bats_left                            1.975850
# throws_left                          3.885031
# batter_order                         2.104509
# field_out                            6.357465
# strikeout                            4.984669
# single                               4.107727
# walk                                 3.700456
# double                               2.663535
# home_run                             3.758639
# cum_post_runner_on_first             5.245022
# inning_cum_post_runner_on_first      9.223057
# cum_post_runner_on_second            3.208476
# inning_cum_post_runner_on_second     4.890097
# cum_post_runner_on_third             2.731634
# inning_cum_post_runner_on_third      2.979380
# cum_bats_right                            inf
# cum_bats_left                             inf
# inning_cum_bats_left                 4.438973
# cum_opposite_actual                  4.461346
# inning_cum_opposite_actual           6.249059
# cum_field_out                        8.209585
# inning_cum_field_out                 9.684999
# cum_strikeout                        6.536146
# inning_cum_strikeout                 6.924596
# cum_single                           7.362101
# inning_cum_single                    9.598381
# cum_walk                             5.099362
# inning_cum_walk                      6.609081
# cum_double                           7.634607
# inning_cum_double                    5.830331
# cum_home_run                        18.708300
# inning_cum_home_run                  6.524715
# cum_points_allowed                  15.074008
# points_allowed                       3.194086
# inning_cum_points_allowed           16.172666
# hot_cold_field_out                   3.804505
# hot_cold_strikeout                   3.042560
# hot_cold_single                      2.440380
# hot_cold_walk                        1.760962
# hot_cold_double                      1.597965
# hot_cold_home_run                    2.427909
# hot_cold_points_allowed              2.275183
# pas_since_post_runner_on_first       3.009599
# has_have_post_runner_on_first        1.154397
# pas_since_post_runner_on_second      2.419282
# has_have_post_runner_on_second       1.778476
# pas_since_post_runner_on_third       2.548415
# has_have_post_runner_on_third        3.474278
# pas_since_field_out                  2.465243
# has_have_field_out                   0.000000
# pas_since_strikeout                  1.934378
# has_have_strikeout                   1.160531
# pas_since_single                     2.885735
# has_have_single                      1.764334
# pas_since_walk                       3.092343
# has_have_walk                        3.942870
# pas_since_double                     4.091068
# has_have_double                      6.323412
# pas_since_home_run                   4.386299
# has_have_home_run                    7.562421
# pas_since_points_allowed             2.713083
# has_have_points_allowed              2.760404
# constant                             0.000000
# dtype: float64

# %%
X_train2.drop(['cum_bats_right'], axis=1, inplace=True)

vif=pd.Series([variance_inflation_factor(X_train2.values, i) 
               for i in range(X_train2.shape[1])], 
              index=X_train2.columns)

vif
# Out:
# pbp_idx                             31.981824
# inning                              20.937132
# postouts                            16.126162
# pitches_in_pa                        1.331217
# pitch_total                          2.798351
# er_total                            12.996944
# runners_on_base                     15.674353
# score_diff                           1.713426
# tying_run_on                         1.155812
# total_bases_allowed                 25.890330
# opposite_hand                        1.291172
# end_of_inning                        3.217982
# previously_walk                      1.908723
# consec_walks                         1.100516
# double_header                        1.034232
# home_team                            1.045025
# opposite_actual                      2.067031
# bats_left                            1.975850
# throws_left                          3.885031
# batter_order                         2.104509
# field_out                            6.357465
# strikeout                            4.984669
# single                               4.107727
# walk                                 3.700456
# double                               2.663535
# home_run                             3.758639
# cum_post_runner_on_first             5.245022
# inning_cum_post_runner_on_first      9.223057
# cum_post_runner_on_second            3.208476
# inning_cum_post_runner_on_second     4.890097
# cum_post_runner_on_third             2.731634
# inning_cum_post_runner_on_third      2.979380
# cum_bats_left                        3.995695
# inning_cum_bats_left                 4.438973
# cum_opposite_actual                  4.461346
# inning_cum_opposite_actual           6.249059
# cum_field_out                        8.209585
# inning_cum_field_out                 9.684999
# cum_strikeout                        6.536146
# inning_cum_strikeout                 6.924596
# cum_single                           7.362101
# inning_cum_single                    9.598381
# cum_walk                             5.099362
# inning_cum_walk                      6.609081
# cum_double                           7.634607
# inning_cum_double                    5.830331
# cum_home_run                        18.708300
# inning_cum_home_run                  6.524715
# cum_points_allowed                  15.074008
# points_allowed                       3.194086
# inning_cum_points_allowed           16.172666
# hot_cold_field_out                   3.804505
# hot_cold_strikeout                   3.042560
# hot_cold_single                      2.440380
# hot_cold_walk                        1.760962
# hot_cold_double                      1.597965
# hot_cold_home_run                    2.427909
# hot_cold_points_allowed              2.275183
# pas_since_post_runner_on_first       3.009599
# has_have_post_runner_on_first        1.154397
# pas_since_post_runner_on_second      2.419282
# has_have_post_runner_on_second       1.778476
# pas_since_post_runner_on_third       2.548415
# has_have_post_runner_on_third        3.474278
# pas_since_field_out                  2.465243
# has_have_field_out                   0.000000
# pas_since_strikeout                  1.934378
# has_have_strikeout                   1.160531
# pas_since_single                     2.885735
# has_have_single                      1.764334
# pas_since_walk                       3.092343
# has_have_walk                        3.942870
# pas_since_double                     4.091068
# has_have_double                      6.323412
# pas_since_home_run                   4.386299
# has_have_home_run                    7.562421
# pas_since_points_allowed             2.713083
# has_have_points_allowed              2.760404
# constant                             0.000000
# dtype: float64

# %%
X_train2=X_train2.drop(['total_bases_allowed'], axis=1)

vif=pd.Series([variance_inflation_factor(X_train2.values, i) 
               for i in range(X_train2.shape[1])], 
              index=X_train2.columns)

vif
# Out:
# pbp_idx                             26.671192
# inning                              19.332278
# postouts                            16.049718
# pitches_in_pa                        1.331122
# pitch_total                          2.798006
# er_total                            12.033663
# runners_on_base                     15.601491
# score_diff                           1.710274
# tying_run_on                         1.155407
# opposite_hand                        1.291172
# end_of_inning                        3.214873
# previously_walk                      1.908485
# consec_walks                         1.100477
# double_header                        1.033798
# home_team                            1.044339
# opposite_actual                      2.066978
# bats_left                            1.975814
# throws_left                          3.881081
# batter_order                         2.104504
# field_out                            6.302214
# strikeout                            4.953652
# single                               4.031336
# walk                                 3.669045
# double                               2.472447
# home_run                             3.124071
# cum_post_runner_on_first             5.234382
# inning_cum_post_runner_on_first      9.204334
# cum_post_runner_on_second            3.207764
# inning_cum_post_runner_on_second     4.875375
# cum_post_runner_on_third             2.715014
# inning_cum_post_runner_on_third      2.976297
# cum_bats_left                        3.995146
# inning_cum_bats_left                 4.438760
# cum_opposite_actual                  4.461284
# inning_cum_opposite_actual           6.248734
# cum_field_out                        6.836900
# inning_cum_field_out                 9.676376
# cum_strikeout                        5.629567
# inning_cum_strikeout                 6.915799
# cum_single                           7.057496
# inning_cum_single                    9.597865
# cum_walk                             4.931282
# inning_cum_walk                      6.606770
# cum_double                           5.345323
# inning_cum_double                    5.826715
# cum_home_run                         6.589905
# inning_cum_home_run                  6.512624
# cum_points_allowed                  14.557322
# points_allowed                       3.191088
# inning_cum_points_allowed           16.111807
# hot_cold_field_out                   3.804504
# hot_cold_strikeout                   3.042560
# hot_cold_single                      2.440377
# hot_cold_walk                        1.760904
# hot_cold_double                      1.597797
# hot_cold_home_run                    2.425602
# hot_cold_points_allowed              2.274781
# pas_since_post_runner_on_first       3.009551
# has_have_post_runner_on_first        1.154199
# pas_since_post_runner_on_second      2.419128
# has_have_post_runner_on_second       1.776494
# pas_since_post_runner_on_third       2.548161
# has_have_post_runner_on_third        3.472519
# pas_since_field_out                  2.463942
# has_have_field_out                   0.000000
# pas_since_strikeout                  1.934226
# has_have_strikeout                   1.158662
# pas_since_single                     2.883940
# has_have_single                      1.764301
# pas_since_walk                       3.092261
# has_have_walk                        3.942660
# pas_since_double                     4.089948
# has_have_double                      6.323404
# pas_since_home_run                   4.383643
# has_have_home_run                    7.558429
# pas_since_points_allowed             2.712891
# has_have_points_allowed              2.760232
# constant                             0.000000
# dtype: float64

# %%
X_train2=X_train2.drop(['inning'], axis=1)

vif=pd.Series([variance_inflation_factor(X_train2.values, i) 
               for i in range(X_train2.shape[1])], 
              index=X_train2.columns)

vif
# Out:
# pbp_idx                              8.631360
# postouts                            14.254601
# pitches_in_pa                        1.329694
# pitch_total                          2.796582
# er_total                            11.963453
# runners_on_base                     14.983366
# score_diff                           1.708128
# tying_run_on                         1.154863
# opposite_hand                        1.290859
# end_of_inning                        3.212848
# previously_walk                      1.906733
# consec_walks                         1.099628
# double_header                        1.033759
# home_team                            1.036562
# opposite_actual                      2.066546
# bats_left                            1.975465
# throws_left                          3.879972
# batter_order                         2.104234
# field_out                            6.266783
# strikeout                            4.921763
# single                               4.019676
# walk                                 3.668114
# double                               2.462394
# home_run                             3.117745
# cum_post_runner_on_first             3.804894
# inning_cum_post_runner_on_first      9.093418
# cum_post_runner_on_second            2.645719
# inning_cum_post_runner_on_second     4.752003
# cum_post_runner_on_third             2.487167
# inning_cum_post_runner_on_third      2.950536
# cum_bats_left                        3.994747
# inning_cum_bats_left                 4.438683
# cum_opposite_actual                  4.459557
# inning_cum_opposite_actual           6.228115
# cum_field_out                        6.740858
# inning_cum_field_out                 9.675439
# cum_strikeout                        5.605834
# inning_cum_strikeout                 6.913284
# cum_single                           6.627649
# inning_cum_single                    9.588553
# cum_walk                             4.708081
# inning_cum_walk                      6.594540
# cum_double                           4.912126
# inning_cum_double                    5.823220
# cum_home_run                         5.907850
# inning_cum_home_run                  6.476805
# cum_points_allowed                  12.870540
# points_allowed                       3.190746
# inning_cum_points_allowed           15.937512
# hot_cold_field_out                   3.804488
# hot_cold_strikeout                   3.042285
# hot_cold_single                      2.440371
# hot_cold_walk                        1.760669
# hot_cold_double                      1.597796
# hot_cold_home_run                    2.425374
# hot_cold_points_allowed              2.273260
# pas_since_post_runner_on_first       3.009535
# has_have_post_runner_on_first        1.153299
# pas_since_post_runner_on_second      2.410601
# has_have_post_runner_on_second       1.771687
# pas_since_post_runner_on_third       2.547588
# has_have_post_runner_on_third        3.472515
# pas_since_field_out                  2.463398
# has_have_field_out                   0.000000
# pas_since_strikeout                  1.934208
# has_have_strikeout                   1.156617
# pas_since_single                     2.883252
# has_have_single                      1.764290
# pas_since_walk                       3.090033
# has_have_walk                        3.942473
# pas_since_double                     4.089570
# has_have_double                      6.313938
# pas_since_home_run                   4.381606
# has_have_home_run                    7.558407
# pas_since_points_allowed             2.708608
# has_have_points_allowed              2.755505
# constant                             0.000000
# dtype: float64

# %%
X_train2=X_train2.drop(['runners_on_base'], axis=1)

vif=pd.Series([variance_inflation_factor(X_train2.values, i) 
               for i in range(X_train2.shape[1])], 
              index=X_train2.columns)

vif
# Out:
# pbp_idx                              8.476701
# postouts                             9.823716
# pitches_in_pa                        1.329644
# pitch_total                          2.796559
# er_total                            11.955095
# score_diff                           1.707633
# tying_run_on                         1.146964
# opposite_hand                        1.289425
# end_of_inning                        3.210703
# previously_walk                      1.867428
# consec_walks                         1.099221
# double_header                        1.033707
# home_team                            1.036516
# opposite_actual                      2.061432
# bats_left                            1.974512
# throws_left                          3.879365
# batter_order                         2.103268
# field_out                            6.141757
# strikeout                            4.834446
# single                               3.937646
# walk                                 3.564640
# double                               2.459635
# home_run                             3.070548
# cum_post_runner_on_first             3.791303
# inning_cum_post_runner_on_first      6.140928
# cum_post_runner_on_second            2.642889
# inning_cum_post_runner_on_second     4.038208
# cum_post_runner_on_third             2.479601
# inning_cum_post_runner_on_third      2.632684
# cum_bats_left                        3.984440
# inning_cum_bats_left                 4.404998
# cum_opposite_actual                  4.433230
# inning_cum_opposite_actual           6.099467
# cum_field_out                        6.682339
# inning_cum_field_out                 7.267141
# cum_strikeout                        5.562584
# inning_cum_strikeout                 5.545002
# cum_single                           6.608387
# inning_cum_single                    8.511908
# cum_walk                             4.707378
# inning_cum_walk                      6.348923
# cum_double                           4.904826
# inning_cum_double                    4.798861
# cum_home_run                         5.889255
# inning_cum_home_run                  4.863763
# cum_points_allowed                  12.860855
# points_allowed                       3.160905
# inning_cum_points_allowed            7.605311
# hot_cold_field_out                   3.804338
# hot_cold_strikeout                   3.042018
# hot_cold_single                      2.438190
# hot_cold_walk                        1.760438
# hot_cold_double                      1.597796
# hot_cold_home_run                    2.424963
# hot_cold_points_allowed              2.272646
# pas_since_post_runner_on_first       2.974266
# has_have_post_runner_on_first        1.152470
# pas_since_post_runner_on_second      2.375961
# has_have_post_runner_on_second       1.759290
# pas_since_post_runner_on_third       2.530635
# has_have_post_runner_on_third        3.449703
# pas_since_field_out                  2.426728
# has_have_field_out                   0.000000
# pas_since_strikeout                  1.929324
# has_have_strikeout                   1.156429
# pas_since_single                     2.879606
# has_have_single                      1.762990
# pas_since_walk                       3.076592
# has_have_walk                        3.935634
# pas_since_double                     4.074297
# has_have_double                      6.302986
# pas_since_home_run                   4.381241
# has_have_home_run                    7.549509
# pas_since_points_allowed             2.708132
# has_have_points_allowed              2.754834
# constant                             0.000000
# dtype: float64

# %%
X_train2=X_train2.drop(['er_total'], axis=1)

vif=pd.Series([variance_inflation_factor(X_train2.values, i) 
               for i in range(X_train2.shape[1])], 
              index=X_train2.columns)

vif
# Out:
# pbp_idx                             8.325887
# postouts                            9.823509
# pitches_in_pa                       1.328017
# pitch_total                         2.793942
# score_diff                          1.706734
# tying_run_on                        1.144677
# opposite_hand                       1.288939
# end_of_inning                       3.210592
# previously_walk                     1.866510
# consec_walks                        1.099127
# double_header                       1.033666
# home_team                           1.036511
# opposite_actual                     2.061330
# bats_left                           1.974505
# throws_left                         3.879025
# batter_order                        2.103219
# field_out                           6.141567
# strikeout                           4.833243
# single                              3.936528
# walk                                3.563556
# double                              2.459258
# home_run                            3.070387
# cum_post_runner_on_first            3.755819
# inning_cum_post_runner_on_first     6.140843
# cum_post_runner_on_second           2.586320
# inning_cum_post_runner_on_second    4.037011
# cum_post_runner_on_third            2.473210
# inning_cum_post_runner_on_third     2.632654
# cum_bats_left                       3.982905
# inning_cum_bats_left                4.404696
# cum_opposite_actual                 4.430840
# inning_cum_opposite_actual          6.097582
# cum_field_out                       6.555515
# inning_cum_field_out                7.266816
# cum_strikeout                       5.503272
# inning_cum_strikeout                5.544982
# cum_single                          6.170670
# inning_cum_single                   8.509230
# cum_walk                            4.501464
# inning_cum_walk                     6.348905
# cum_double                          4.669783
# inning_cum_double                   4.793381
# cum_home_run                        5.606870
# inning_cum_home_run                 4.854599
# cum_points_allowed                  4.785406
# points_allowed                      3.160826
# inning_cum_points_allowed           7.577868
# hot_cold_field_out                  3.804337
# hot_cold_strikeout                  3.041773
# hot_cold_single                     2.438098
# hot_cold_walk                       1.759894
# hot_cold_double                     1.597498
# hot_cold_home_run                   2.424936
# hot_cold_points_allowed             2.272566
# pas_since_post_runner_on_first      2.974189
# has_have_post_runner_on_first       1.151853
# pas_since_post_runner_on_second     2.375099
# has_have_post_runner_on_second      1.758754
# pas_since_post_runner_on_third      2.530589
# has_have_post_runner_on_third       3.449688
# pas_since_field_out                 2.426448
# has_have_field_out                  0.000000
# pas_since_strikeout                 1.928786
# has_have_strikeout                  1.156428
# pas_since_single                    2.871006
# has_have_single                     1.759097
# pas_since_walk                      3.075523
# has_have_walk                       3.935171
# pas_since_double                    4.071923
# has_have_double                     6.302928
# pas_since_home_run                  4.370224
# has_have_home_run                   7.544399
# pas_since_points_allowed            2.704438
# has_have_points_allowed             2.754024
# constant                            0.000000
# dtype: float64

# %%
X_train2=X_train2.drop(['postouts'], axis=1)

vif=pd.Series([variance_inflation_factor(X_train2.values, i) 
               for i in range(X_train2.shape[1])], 
              index=X_train2.columns)

vif
# Out:
# pbp_idx                             8.175365
# pitches_in_pa                       1.327844
# pitch_total                         2.793885
# score_diff                          1.706734
# tying_run_on                        1.141700
# opposite_hand                       1.285892
# end_of_inning                       2.491893
# previously_walk                     1.861810
# consec_walks                        1.098312
# double_header                       1.033658
# home_team                           1.036333
# opposite_actual                     2.054695
# bats_left                           1.973265
# throws_left                         3.878628
# batter_order                        2.103208
# field_out                           5.501348
# strikeout                           4.353745
# single                              3.239987
# walk                                3.096091
# double                              2.210150
# home_run                            2.913732
# cum_post_runner_on_first            3.755696
# inning_cum_post_runner_on_first     6.137724
# cum_post_runner_on_second           2.586320
# inning_cum_post_runner_on_second    3.981224
# cum_post_runner_on_third            2.473088
# inning_cum_post_runner_on_third     2.627144
# cum_bats_left                       3.979825
# inning_cum_bats_left                4.374229
# cum_opposite_actual                 4.391628
# inning_cum_opposite_actual          5.987371
# cum_field_out                       6.422340
# inning_cum_field_out                3.799313
# cum_strikeout                       5.423944
# inning_cum_strikeout                3.425446
# cum_single                          6.122025
# inning_cum_single                   8.389215
# cum_walk                            4.462196
# inning_cum_walk                     6.235056
# cum_double                          4.660212
# inning_cum_double                   4.761754
# cum_home_run                        5.596277
# inning_cum_home_run                 4.851446
# cum_points_allowed                  4.783111
# points_allowed                      3.159914
# inning_cum_points_allowed           7.521278
# hot_cold_field_out                  3.803389
# hot_cold_strikeout                  3.041642
# hot_cold_single                     2.438050
# hot_cold_walk                       1.759853
# hot_cold_double                     1.596675
# hot_cold_home_run                   2.424461
# hot_cold_points_allowed             2.272563
# pas_since_post_runner_on_first      2.959912
# has_have_post_runner_on_first       1.151817
# pas_since_post_runner_on_second     2.371819
# has_have_post_runner_on_second      1.757874
# pas_since_post_runner_on_third      2.530517
# has_have_post_runner_on_third       3.449377
# pas_since_field_out                 2.422081
# has_have_field_out                  0.000000
# pas_since_strikeout                 1.928457
# has_have_strikeout                  1.156336
# pas_since_single                    2.869900
# has_have_single                     1.758595
# pas_since_walk                      3.075264
# has_have_walk                       3.930471
# pas_since_double                    4.070092
# has_have_double                     6.300386
# pas_since_home_run                  4.363458
# has_have_home_run                   7.537860
# pas_since_points_allowed            2.702365
# has_have_points_allowed             2.751461
# constant                            0.000000
# dtype: float64

# %%
X_train2=X_train2.drop(['inning_cum_single'], axis=1)

vif=pd.Series([variance_inflation_factor(X_train2.values, i) 
               for i in range(X_train2.shape[1])], 
              index=X_train2.columns)

vif
# Out:
# pbp_idx                             8.159231
# pitches_in_pa                       1.327248
# pitch_total                         2.793882
# score_diff                          1.705492
# tying_run_on                        1.137724
# opposite_hand                       1.285063
# end_of_inning                       2.476882
# previously_walk                     1.826949
# consec_walks                        1.097756
# double_header                       1.033461
# home_team                           1.036309
# opposite_actual                     2.048826
# bats_left                           1.973260
# throws_left                         3.878616
# batter_order                        2.101172
# field_out                           5.498488
# strikeout                           4.353602
# single                              2.869202
# walk                                2.927275
# double                              2.177034
# home_run                            2.911605
# cum_post_runner_on_first            3.659145
# inning_cum_post_runner_on_first     3.983033
# cum_post_runner_on_second           2.574160
# inning_cum_post_runner_on_second    3.685445
# cum_post_runner_on_third            2.473027
# inning_cum_post_runner_on_third     2.523403
# cum_bats_left                       3.976197
# inning_cum_bats_left                4.366223
# cum_opposite_actual                 4.373910
# inning_cum_opposite_actual          5.868651
# cum_field_out                       6.357279
# inning_cum_field_out                3.713093
# cum_strikeout                       5.371417
# inning_cum_strikeout                3.340840
# cum_single                          5.695228
# cum_walk                            4.314194
# inning_cum_walk                     4.121761
# cum_double                          4.607714
# inning_cum_double                   4.165688
# cum_home_run                        5.570333
# inning_cum_home_run                 4.598157
# cum_points_allowed                  4.763678
# points_allowed                      3.114969
# inning_cum_points_allowed           6.481432
# hot_cold_field_out                  3.795375
# hot_cold_strikeout                  3.038150
# hot_cold_single                     2.432254
# hot_cold_walk                       1.759096
# hot_cold_double                     1.596026
# hot_cold_home_run                   2.421730
# hot_cold_points_allowed             2.272032
# pas_since_post_runner_on_first      2.929148
# has_have_post_runner_on_first       1.151342
# pas_since_post_runner_on_second     2.369805
# has_have_post_runner_on_second      1.757405
# pas_since_post_runner_on_third      2.530422
# has_have_post_runner_on_third       3.446983
# pas_since_field_out                 2.393903
# has_have_field_out                  0.000000
# pas_since_strikeout                 1.928138
# has_have_strikeout                  1.155705
# pas_since_single                    2.660730
# has_have_single                     1.729076
# pas_since_walk                      3.070372
# has_have_walk                       3.925764
# pas_since_double                    4.069928
# has_have_double                     6.299612
# pas_since_home_run                  4.363446
# has_have_home_run                   7.536985
# pas_since_points_allowed            2.701478
# has_have_points_allowed             2.748326
# constant                            0.000000
# dtype: float64

# %%
X_train2=X_train2.drop(['has_have_home_run'], axis=1)

vif=pd.Series([variance_inflation_factor(X_train2.values, i) 
               for i in range(X_train2.shape[1])], 
              index=X_train2.columns)

vif
# Out:
# pbp_idx                             8.083122
# pitches_in_pa                       1.327095
# pitch_total                         2.792169
# score_diff                          1.704547
# tying_run_on                        1.137535
# opposite_hand                       1.284897
# end_of_inning                       2.476856
# previously_walk                     1.826933
# consec_walks                        1.097732
# double_header                       1.033079
# home_team                           1.036308
# opposite_actual                     2.048716
# bats_left                           1.973253
# throws_left                         3.877883
# batter_order                        2.101094
# field_out                           5.498336
# strikeout                           4.353143
# single                              2.868717
# walk                                2.927198
# double                              2.176061
# home_run                            2.894318
# cum_post_runner_on_first            3.658978
# inning_cum_post_runner_on_first     3.980792
# cum_post_runner_on_second           2.572893
# inning_cum_post_runner_on_second    3.682429
# cum_post_runner_on_third            2.471481
# inning_cum_post_runner_on_third     2.523326
# cum_bats_left                       3.974402
# inning_cum_bats_left                4.363113
# cum_opposite_actual                 4.371554
# inning_cum_opposite_actual          5.866042
# cum_field_out                       6.346518
# inning_cum_field_out                3.712793
# cum_strikeout                       5.366931
# inning_cum_strikeout                3.340700
# cum_single                          5.692900
# cum_walk                            4.308463
# inning_cum_walk                     4.121702
# cum_double                          4.604019
# inning_cum_double                   4.152098
# cum_home_run                        4.122427
# inning_cum_home_run                 4.319503
# cum_points_allowed                  4.743443
# points_allowed                      3.110467
# inning_cum_points_allowed           6.470501
# hot_cold_field_out                  3.795375
# hot_cold_strikeout                  3.038122
# hot_cold_single                     2.432248
# hot_cold_walk                       1.759050
# hot_cold_double                     1.594990
# hot_cold_home_run                   2.418498
# hot_cold_points_allowed             2.272016
# pas_since_post_runner_on_first      2.923885
# has_have_post_runner_on_first       1.151306
# pas_since_post_runner_on_second     2.369801
# has_have_post_runner_on_second      1.757397
# pas_since_post_runner_on_third      2.507074
# has_have_post_runner_on_third       3.426002
# pas_since_field_out                 2.393902
# has_have_field_out                  0.000000
# pas_since_strikeout                 1.928132
# has_have_strikeout                  1.155704
# pas_since_single                    2.660234
# has_have_single                     1.728873
# pas_since_walk                      3.069738
# has_have_walk                       3.923904
# pas_since_double                    4.051251
# has_have_double                     6.276180
# pas_since_home_run                  1.888572
# pas_since_points_allowed            2.409167
# has_have_points_allowed             2.371215
# constant                            0.000000
# dtype: float64

# %%
vif.max()
# Out:
# 8.083122385426854

# %%
X_train2.drop('constant', axis=1, inplace=True)

# %%
X_test=X_test[X_train2.columns.tolist()]

# %%
X_train2.to_pickle('Datasets/X_train.plk')
X_test.to_pickle('Datasets/X_test.plk')
y_train2.to_pickle('Datasets/Y_train.plk')
y_test.to_pickle('Datasets/Y_test.plk')
